# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("BlackFriday.csv")

# %% [markdown]
# ## walkthrough

# %% [raw]
# df.sample(10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 537549  1004734  P00345842      M  51-55           1             B
# 537551  1004735  P00313442      M  46-50           3             C
# 537562  1004736  P00146742      M  18-25          20             A
# 537571  1004737  P00221442      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# ## Analyzing columns

# %%
df["User_ID"].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
df["Product_ID"].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00038842',
#        'P00295642', 'P00091742'], dtype=object)

# %%
df["Gender"].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df["Occupation"].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6], dtype=int64)

# %%
df["City_Category"].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df["Stay_In_Current_City_Years"].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df["Marital_Status"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["Product_Category_1"].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9], dtype=int64)

# %%
df["Purchase"].unique()
# Out:
# array([ 8370, 15200,  1422, ..., 14539, 11120, 18426], dtype=int64)

# %%
for i in df.columns:
    print(i,df[i].nunique())
# Out:
# User_ID 5891
# Product_ID 3623
# Gender 2
# Age 7
# Occupation 21
# City_Category 3
# Stay_In_Current_City_Years 5
# Marital_Status 2
# Product_Category_1 18
# Purchase 17959

# %% [markdown]
# ## analysing gender

# %%
fd= pd.DataFrame({"Ratio":[len(df[df["Gender"] == "M"]),len(df[df["Gender"] == "F"])]},index = ["Male","Female"])

# %%
fd
# Out:
#          Ratio
# Male    405380
# Female  132197

# %%
fd.plot.pie( y = "Ratio" , autopct = "%.2f" )
# Out:
# <Axes: ylabel='Ratio'>

# %%
df.groupby("Gender").size()
# Out:
# Gender
# F    132197
# M    405380
# dtype: int64

# %%
df.groupby("Gender").size().plot(kind = "pie" , autopct = "%.2f")
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby("Gender")["Purchase"].sum().plot(kind = "pie" , autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("Gender")["Purchase"].mean().plot(kind = "pie" , autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Analysing age and marital status

# %%
df.groupby("Age").size().plot(kind = "bar",figsize = (6,6) , title = "age")
# Out:
# <Axes: title={'center': 'age'}, xlabel='Age'>

# %%
df.shape
# Out:
# (537577, 10)

# %%
len(df[df["Age"] == "0-17"]["Product_ID"])
# Out:
# 14707

# %%
df[df["Age"] == "0-17"]["Product_ID"].nunique()
# Out:
# 2300

# %%
# print("Age","Total","unique")
lst = []
for i in df["Age"].unique():
    lst.append((i ,len(df[df["Age"] == i]["Product_ID"]) ,df[df["Age"] == i]["Product_ID"].nunique()))
new = pd.DataFrame(lst,columns = ["Age","Total purchased" , "unique purchase"])
new
# Out:
#      Age  Total purchased  unique purchase
# 0   0-17            14707             2300
# 1    55+            20903             2573
# 2  26-35           214690             3419
# 3  46-50            44526             3099
# 4  51-55            37618             2877
# 5  36-45           107499             3318
# 6  18-25            97634             3213

# %%
new.plot.bar("Age")
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby("Age")["Purchase"].sum().plot(kind = "bar",figsize = (6,6) , title = "age")
# Out:
# <Axes: title={'center': 'age'}, xlabel='Age'>

# %%
df.groupby("Age")["Purchase"].mean().plot(kind = "bar",figsize = (6,6) , title = "age")
# Out:
# <Axes: title={'center': 'age'}, xlabel='Age'>

# %%
df.groupby("Age")["User_ID"].count()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# Name: User_ID, dtype: int64

# %%
df.groupby("Age")["Purchase"].count()
# Out:
# Age
# 0-17      14707
# 18-25     97634
# 26-35    214690
# 36-45    107499
# 46-50     44526
# 51-55     37618
# 55+       20903
# Name: Purchase, dtype: int64

# %%
df.groupby("Age")["Purchase"].mean().plot(kind = "pie",figsize = (6,6) , title = "age" ,autopct = "%.1f")
# Out:
# <Axes: title={'center': 'age'}, ylabel='Purchase'>

# %%
df.groupby("Marital_Status").size().plot(kind = "pie",figsize = (6,6) , title = "age" ,autopct = "%.1f")
# Out:
# <Axes: title={'center': 'age'}>

# %% [markdown]
# ## Analysing multiple column

# %%
sns.set(rc = {"figure.figsize": (12,6)})
sns.countplot(data = df , hue = "Gender" , x = "Age")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {"figure.figsize": (12,6)})
sns.countplot(data = df , hue = "Gender" , x = "Marital_Status")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.set(rc = {"figure.figsize": (12,6)})
sns.countplot(data = df ,x = "Gender",hue = "Marital_Status" )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 2
#       1 sns.set(rc = {"figure.figsize": (12,6)})
# ----> 2 sns.countplot(data = df ,x = "Gender",hue = "Marital_Status" )
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(data = df ,x = "City_Category",hue = "Age" )
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data = df ,x = "Age",hue =  "City_Category")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.groupby("City_Category").size().plot(kind = "pie" ,figsize = (5,5) , title = "city", autopct = "%.2f")
# Out:
# <Axes: title={'center': 'city'}>

# %%
sns.countplot(data = df ,x = "Gender" ,hue =  "City_Category")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.groupby("City_Category")["Purchase"].sum().plot(kind = "pie" , autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby("City_Category")["Purchase"].mean().plot(kind = "pie" , autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
ls = df.groupby("City_Category").size().values
# print(ls.iloc[0])

# %%
lst= df.groupby("City_Category")["Purchase"].sum().values
# print(lst.iloc[0])

# %%
lt = df["City_Category"].unique()
sum= 0
for i in range(len(ls)):
    sum +=lst[i]/ls[i]
    print(lst[i]/ls[i])
print("*"*10)
for i in range(len(ls)):
    
    print((lst[i]/ls[i])/sum)
# Out:
# 8958.011013703177
# 9198.657848145418
# 9844.44185501604
# **********
# 0.319916274189363
# 0.32851046307263837
# 0.3515732627379987

# %%
df.groupby("City_Category")["Purchase"].mean().plot(kind = "pie" ,autopct = "%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# ## Occupation and Product Analysis
